# %%
import pandas as pd
import matplotlib.pyplot as plt
file = "/data/pt_01880/test.parquet"
dtf = pd.read_parquet(file)

plt.hist(dtf["lambda"])
# Out:
# (array([2.000e+00, 1.028e+03, 3.570e+03, 1.965e+03, 5.620e+02, 7.710e+02,
#         2.380e+02, 2.210e+02, 1.030e+02, 2.260e+02]),
#  array([0. , 0.8, 1.6, 2.4, 3.2, 4. , 4.8, 5.6, 6.4, 7.2, 8. ]),
#  <BarContainer object of 10 artists>)
